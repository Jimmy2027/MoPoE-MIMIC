# %%
from notebooks.utils import graphs
from matplotlib import pyplot as plt
import os
import graphviz

# %%
import os
print(os.getcwd())
# Out:
# /Users/Hendrik/Documents/master3/leomed_mimic/mimic/notebooks

# %%
graphs.draw_text_word_workflow_graph()
graphs.draw_mmvae_forward_graph()
# Out:
# drawing graph to utils/text_word_workflow.dot

# %% [markdown]
# ### When calculating coherence, the workflow looks like this:w
# with bs the batch size and vs the vocab size

# %%
with open("utils/text_word_workflow.dot") as f:
    dot_graph = f.read()

graphviz.Source(dot_graph)

# %% [markdown]
# # Graph representing the forward pass of the MMVAE

# %%
with open("utils/mmvae_forward_graph.dot") as f:
    dot_graph = f.read()

graphviz.Source(dot_graph)
